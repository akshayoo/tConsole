# %%
import pandas as pd

# %%
data = pd.read_csv("template.ncounter.csv")

# %%
data.head()
# Out:
#   Sample ID               Description  RNA Conc.                      Notes  \
# 0      S009     Tumor tissue – breast      267.4                High purity
# 1      S010     Tumor tissue – breast      254.1          Minor degradation
# 2      S011     Tumor tissue – breast      279.6            Excellent yield
# 3      S012  Adjacent normal – breast      198.5                        NaN
# 4      S013  Adjacent normal – breast      187.9  Slight salt contamination
#
#   Replicate(Group Name)
# 0          Rep1 (Tumor)
# 1          Rep2 (Tumor)
# 2          Rep3 (Tumor)
# 3         Rep1 (Normal)
# 4         Rep2 (Normal)

# %%
column_list = ["sample_id", "description", "concentration", "replicate_group", "notes"]

# %%
data.columns = column_list

# %%
data.columns
# Out:
# Index(['sample_id', 'description', 'concentration', 'replicate_group',
#        'notes'],
#       dtype='str')

# %%
ecords = data.fillna("No Value").to_dict(orient="records")

# %%
ecords
# Out:
# [{'Sample ID': 'S009',
#   'Description': 'Tumor tissue – breast',
#   'RNA Conc.': 267.4,
#   'Notes': 'High purity',
#   'Replicate(Group Name)': 'Rep1 (Tumor)'},
#  {'Sample ID': 'S010',
#   'Description': 'Tumor tissue – breast',
#   'RNA Conc.': 254.1,
#   'Notes': 'Minor degradation',
#   'Replicate(Group Name)': 'Rep2 (Tumor)'},
#  {'Sample ID': 'S011',
#   'Description': 'Tumor tissue – breast',
#   'RNA Conc.': 279.6,
#   'Notes': 'Excellent yield',
#   'Replicate(Group Name)': 'Rep3 (Tumor)'},
#  {'Sample ID': 'S012',
#   'Description': 'Adjacent normal – breast',
#   'RNA Conc.': 198.5,
#   'Notes': 'No Value',
#   'Replicate(Group Name)': 'Rep1 (Normal)'},
#  {'Sample ID': 'S013',
#   'Description': 'Adjacent normal – breast',
#   'RNA Conc.': 187.9,
#   'Notes': 'Slight salt contamination',
#   'Replicate(Group Name)': 'Rep2 (Normal)'},
#  {'Sample ID': 'S014',
#   'Description': 'Adjacent normal – breast',
#   'RNA Conc.': 205.3,
#   'Notes': 'Sequencing ready',
# ...

# %%
sample_id = list(data["Sample ID"].fillna("No Value").values)
description = list(data["Description"].fillna("No Value").values)
rna_conc = list(data["RNA Conc."].fillna("No Value").values)
notes = list(data["Notes"].fillna("No Value").values)
repl_groupname = list(data["Replicate(Group Name)"].fillna("No Value").values)

# %%
sample_id
# Out:
# ['S009',
#  'S010',
#  'S011',
#  'S012',
#  'S013',
#  'S014',
#  'S015',
#  'S016',
#  'S017',
#  'S018',
#  'S019',
#  'S020',
#  'S021',
#  'S022',
#  'S023',
#  'S024',
#  'S025',
#  'S026']

# %%
notes
# Out:
# ['High purity',
#  'Minor degradation',
#  'Excellent yield',
#  'No Value',
#  'Slight salt contamination',
#  'Sequencing ready',
#  'No Value',
#  'Good integrity',
#  'Suitable for library prep',
#  'No Value',
#  'Acceptable quality',
#  'Stable RNA',
#  'No Value',
#  'Slight foaming observed',
#  'Consistent yield',
#  'Control baseline',
#  'Mild degradation',
#  'Good for downstream analysis']

# %%
from pymongo import MongoClient

# %%
CLIENT = MongoClient("mongodb://localhost:27017")

db = CLIENT.tcDB

# %%
collections = db["tcStdDeliverables"]

data = collections.find({"category" : "Bulk Transcriptomics"}, {"_id" : 0})

# %%
from pprint import pprint
for doc in data:
    pprint(doc)
# Out:
# {'category': 'Bulk Transcriptomics',
#  'services': [{'applications': 'Method utilizes directional RNA libraries to '
#                                'process poly(A)+ enriched RNA into NGS '
#                                'libraries. Suitable for proﬁling changes in '
#                                'gene expression for biological discovery. The '
#                                'project can involve understanding differences '
#                                'between control vs treatment, or proﬁling '
#                                'changes across time-course or developmental '
#                                'series. Projects often use multiple biological '
#                                'replicates, analyzed to provide precision in '
#                                'inference of gene expression changes.',
#                'input_requirements': {'input_amount_ng': {'max': 500,
#                                                           'min': 100},
# ...

# %%
empt_list = []

std_del = ["wejnkwenfkjerfjker", "wfifneijfnkejfnej", "ejfhejbfhejbfheb", "hwebjhebfjherbfehj"]


for i in std_del:
    empty_dict = {
        "label" : i,
        "completed" : False,
        "completed_at" : ""
    }

    empt_list.append(empty_dict)

# %%
empt_list
# Out:
# [{'label': 'wejnkwenfkjerfjker', 'completed': False, 'completed_at': ''},
#  {'label': 'wfifneijfnkejfnej', 'completed': False, 'completed_at': ''},
#  {'label': 'ejfhejbfhejbfheb', 'completed': False, 'completed_at': ''},
#  {'label': 'hwebjhebfjherbfehj', 'completed': False, 'completed_at': ''}]

# %%
from pprint import pprint
from pymongo import MongoClient

CLIENT = MongoClient("mongodb://localhost:27017")

db = CLIENT.tcDB

collections = db["tcProjects"]

data = collections.find({}, 
                        {"_id": 0,
                         "project_id" : 1,
                         "project_details.standard_deliverables.completed" : 1,
                         "project_details.added_deliverables.completed" : 1,
                         "form_status" : 1
                         })

# %%
list_elements = []

for doc in data:
    list_elements.append(doc)

# %%
list_elements
# Out:
# [{'project_id': 'TIPL_100',
#   'project_details': {'standard_deliverables': [{'completed': False},
#     {'completed': False},
#     {'completed': False},
#     {'completed': False},
#     {'completed': False},
#     {'completed': False},
#     {'completed': False}],
#    'added_deliverables': [{'completed': False}, {'completed': False}]},
#   'form_status': {'project_info': True,
#    'service_info': True,
#    'project_details': True,
#    'sample_submission': True,
#    'method': False,
#    'qc': False,
#    'library': False,
#    'bioinformatics': False}},
#  {'project_id': 'TIPL_200',
#   'project_details': {'standard_deliverables': [{'completed': False},
#     {'completed': False},
#     {'completed': False},
#     {'completed': False},
#     {'completed': False}],
#    'added_deliverables': [{'completed': False}]},
#   'form_status': {'project_info': True,
#    'service_info': True,
#    'project_details': True,
#    'sample_submission': True,
#    'method': False,
# ...

# %%
data = list_elements[0].get("form_status")

# %%
data
# Out:
# {'project_info': True,
#  'service_info': True,
#  'project_details': True,
#  'sample_submission': True,
#  'method': False,
#  'qc': False,
#  'library': False,
#  'bioinformatics': False}

# %%
list(data.values()).count(True)
# Out:
# 4

# %%
list_elements[0].get("project_details").get("standard_deliverables")
# Out:
# 7

# %%
list_elements[0].get("project_details").get("standard_deliverables")
# Out:
# [{'completed': False},
#  {'completed': False},
#  {'completed': False},
#  {'completed': False},
#  {'completed': False},
#  {'completed': False},
#  {'completed': False}]

# %%
list_elements[0].get("project_details").get("standard_deliverables").count(False)
# Out:
# 0

# %%
data = [{'completed': False}, {'completed': False}, {'completed': False}, 
        {'completed': False}, {'completed': False}, {'completed': False}, 
        {'completed': False}]

false_count = sum(1 for d in data if d['completed'] is True)

# %%
false_count
# Out:
# 0

# %%
true_count = 0

for d in data: 
    if d['completed'] is True:
        true_count += 1

# %%
project_id = list_elements[0].get("project_id", "")
std_comp =  list_elements[0].get("project_details").get("standard_deliverables", [])
add_comp = list_elements[0].get("project_details").get("added_deliverables", [])

total_elem = len(std_comp) + len(add_comp)

true_count = 0

for std in std_comp:
    if std["completed"] is True:
        true_count += 1

for add in add_comp:
    if add["completed"] is True:
        true_count + 1

project_completion = true_count/total_elem *100

get_status =  list_elements[0].get("form_status")


def get_project_status(flags: dict) -> str:

    if flags.get("bioinformatics"):
        return "Completed"

    if flags.get("library"):
        return "Bioinformatics Stage"

    if flags.get("qc"):
        return "Library Stage"

    if flags.get("method"):
        return "In QC Stage"

    if flags.get("sample_submission"):
        return "Accepted"

    return "Initiated"

status = get_project_status(get_status)

# %%
status
# Out:
# 'Accepted'

# %%
project_completion
# Out:
# 0.0

# %%
from pprint import pprint
from pymongo import MongoClient

CLIENT = MongoClient("mongodb://localhost:27017")

db = CLIENT.tcDB

collections = db["tcProjects"]

data = collections.find({}, 
                        {"_id": 0,
                         "project_id" : 1,
                         "project_details.standard_deliverables.completed" : 1,
                         "project_details.added_deliverables.completed" : 1,
                         "form_status" : 1
                         })

list_elements = []

payload = []

for doc in data:
    list_elements.append(doc)

for i in range(len(list_elements)):
    project_id = list_elements[i].get("project_id", "")
    std_comp =  list_elements[i].get("project_details").get("standard_deliverables", [])
    add_comp = list_elements[i].get("project_details").get("added_deliverables", [])

    total_elem = len(std_comp) + len(add_comp)

    true_count = 0

    for std in std_comp:
        if std["completed"] is True:
            true_count += 1

    for add in add_comp:
        if add["completed"] is True:
            true_count + 1

    project_completion = true_count/total_elem *100

    get_status =  list_elements[0].get("form_status")

    def get_project_status(flags: dict) -> str:

        if flags.get("bioinformatics"):
            return "Completed"

        if flags.get("library"):
            return "Bioinformatics Stage"

        if flags.get("qc"):
            return "Library Stage"

        if flags.get("method"):
            return "In QC Stage"

        if flags.get("sample_submission"):
            return "Accepted"

        return "Initiated"

    status = get_project_status(get_status)

    project = {
        "project_id" : project_id,
        "percent" : project_completion,
        "status" : status
    }

    payload.append(project)

# %%
payload
# Out:
# [{'project_id': 'TIPL_100', 'percent': 0.0, 'status': 'Accepted'},
#  {'project_id': 'TIPL_200', 'percent': 0.0, 'status': 'Accepted'},
#  {'project_id': 'TIPL_300', 'percent': 0.0, 'status': 'Accepted'},
#  {'project_id': 'TIPL_400', 'percent': 0.0, 'status': 'Accepted'}]

# %%
from pprint import pprint
from pymongo import MongoClient

CLIENT = MongoClient("mongodb://localhost:27017")

db = CLIENT.tcDB

collections = db["tcProjects"]

data = collections.find_one({"project_id" : "TIPL_200"}, {"_id" : 0,
                                            "sample_submission.service_technology" : 1,
                                            "sample_submission.details.application" : 1,
                                            "sample_submission.details.replicates": 1,
                                            "sample_submission.details.extraction_needed" : 1,
                                            "sample_submission.details.nucleases" : 1,
                                            "sample_submission.details.kit_name" : 1,
                                            "sample_submission.details.qc_accessed" : 1,
                                            "sample_submission.details.bioinformatics_required" : 1,
                                            "sample_submission.details.key_objectives" : 1,
                                            "sample_submission.details.comparisons" : 1,
                                            "sample_submission.details.additional_analysis" : 1,
                                            "sample_submission.details.reference_studies" : 1,
                                            "sample_submission.details.sample_details" : 1
                                            })

# %%
data
# Out:
# {'sample_submission': {'service_technology': 'nCounter',
#   'details': {'application': 'mRNA',
#    'replicates': False,
#    'extraction_needed': False,
#    'nucleases': False,
#    'kit_name': '',
#    'qc_accessed': '',
#    'bioinformatics_required': True,
#    'key_objectives': 'Objectives discussed',
#    'comparisons': 'All type of comparisons',
#    'additional_analysis': 'All additional analysis',
#    'reference_studies': 'PMID253',
#    'sample_details': [{'Sample ID': 'S009',
#      'Description': 'Tumor tissue – breast',
#      'RNA Conc.': 267.4,
#      'Notes': 'High purity',
#      'Replicate(Group Name)': 'Rep1 (Tumor)'},
#     {'Sample ID': 'S010',
#      'Description': 'Tumor tissue – breast',
#      'RNA Conc.': 254.1,
#      'Notes': 'Minor degradation',
#      'Replicate(Group Name)': 'Rep2 (Tumor)'},
#     {'Sample ID': 'S011',
#      'Description': 'Tumor tissue – breast',
#      'RNA Conc.': 279.6,
#      'Notes': 'Excellent yield',
# ...

# %%
from weasyprint import HTML
HTML(string="<p>document</p>").write_pdf("document.pdf", pdf_variant="pdf/a-3u")

# %%
template = """
<html lang="en">
    <head>
        <meta charset="UTF-8">
        <title>QC Report</title>

        <style>
            @page {
                size: A4;
                margin: 1cm;
            }
            .a4-page {
                background-color: #ffffff;
            }

            body {
                background-color: #e0e0e0;
                display: flex;
                justify-content: center;
                align-items: center;
                min-height: 100vh;
                margin: 0;
                font-family: "Sofia", sans-serif;
            }

            h1, p {
                margin-bottom: 10px;
            }

            .header-comp {
                background-color: rgb(170, 204, 45);
                height: 20px;
            }

            .header-div {
                display: flex;
                margin: 5px;
                align-self: center;
                height: 50px;
            }
            .header-img{
                margin-left: auto;
            }

            .header-img img {
                margin-right: 30px;
                height: 50px;
                padding: 5px;
            }

            .header-comp2 {
                margin: 5px;
                height: 25px;
                background-color: #0e4a66;
            }

            .header-comp2 h3 {
                margin-left: 30px;
                color: #ffffff;
                padding: 4px;
            }

            .general-cont {
                margin-left: 50px;
                margin-right: 50px;
            }

            .grid-inside-comp {
                display: grid;
                grid-template-columns: 1fr 1fr;
            }

            .grid-inside-comp > div:first-child,
            .grid-inside-comp > div:last-child{
                padding: 5px;
                display: flex;
                justify-content: center;
                border: 1px solid #ffffff;
                background-color: #e0e0e0;
            }

            .overview-head {
                display: flex;
                justify-content: center;
            }

            .grid-comp-tr {
                display: grid;
                grid-template-columns: 1fr 1fr 1fr;
            }

            .grid-comp-tr-in {
                padding: 5px;
                border: 1px dashed #0e4a66;
                border-radius: 5px;
                margin: 2px;
            }

            .grid-comp-tr-in  > div:first-child,
            .grid-comp-tr-in > div:last-child{
                padding: 5px;
                display: flex;
                justify-content: center;
            }

            .grid-comp-tr-in  > div:first-child{
                background-color: #0e4a66;
                color: #ffffff;
                border-radius: 4px;
            }

            .grid-comp-tr-in > div:last-child {
                border-top: 1px dotted gray;
                color: #0e4a66;
            }

            .styled-table {
                border-collapse: collapse;
                margin: 25px 0;
                font-size: 0.9em;
                font-family: sans-serif;
                width: 100%;
            }

            .styled-table thead tr {
                background-color: #0e4a66;
                color: #ffffff;
                text-align: left;
            }

            .styled-table th,
            .styled-table td {
                padding: 8px 10px;
            }
            .styled-table tbody tr {
                border-bottom: 1px solid #dddddd;
            }

            .styled-table tbody tr:nth-of-type(even) {
                background-color: #f3f3f3;
            }

            .styled-table tbody tr:last-of-type {
                border-bottom: 2px solid #0e4a66;;
            }

            .styled-table tbody tr.active-row {
                font-weight: bold;
                color: #009879;
            }

            div{
                color: #303030;
                font-size: 14px;
            }

            h3 {
                color: #0e4a66;
                font-size: 16px;
            }

            .footer-comp {
                margin-right: 10px;
            }





        </style>
    </head>

    <body>
        <div class="a4-page">
            <div class="header-comp"></div>
            <div class="header-div">
                <div class="header-img">
                    <img src="./logo.webp" alt="theracues logo">
                </div>
            </div>
            <div class="header-comp2">
                <h3>QC REPORT</h3>
            </div>
            <div class="general-cont">
                <div class="overview-head">
                    <h3>GENERAL INFO</h3>
                </div>
                <div class="grid-comp">
                    <div class="grid-inside-comp">
                        <div>Project ID</div>
                        <div>TIPL_100</div>
                    </div>
                    <div class="grid-inside-comp">
                        <div>Client Name</div>
                        <div>Dr. Tutu manoharan</div>
                    </div>
                    <div class="grid-inside-comp">
                        <div>Institution/ Organization</div>
                        <div>IIT Madras</div>
                    </div>
                    <div class="grid-inside-comp">
                        <div>Lab/ Department </div>
                        <div>Cosmology Lab</div>
                    </div>
                    <div class="grid-inside-comp">
                        <div>QC Report Date</div>
                        <div>02/02/2025</div>
                    </div>
                </div>
            </div>
            <div class="general-cont">
                <div class="overview-head">
                    <h3>PROJECT OVERVIEW</h3>
                </div>
                <div class="grid-comp-tr">
                    <div class="grid-comp-tr-in">
                        <div>Service Offered</div>
                        <div>Exome- Standard (Germline)</div>
                    </div>
                    <div class="grid-comp-tr-in">
                        <div>Sample Type</div>
                        <div>FFPE Tissue</div>
                    </div>
                    <div class="grid-comp-tr-in">
                        <div>Application</div>
                        <div>RNA</div>
                    </div>
                </div>
                <div class="grid-comp-tr">
                    <div class="grid-comp-tr-in">
                        <div>Extraction</div>
                        <div>Yes</div>
                    </div>
                    <div class="grid-comp-tr-in">
                        <div>Number of samples</div>
                        <div>344</div>
                    </div>
                    <div class="grid-comp-tr-in">
                        <div>Platform</div>
                        <div>Tapestation and Quibit</div>
                    </div>
                </div>
            </div>

            <div class="general-cont">
                <div class="overview-head">
                    <h3>QC DETAILS</h3>
                </div>
                    <table class="styled-table">
                        <thead>
                            <tr>
                                <th>Sample ID</th>
                                <th>theraCUES Sample ID</th>
                                <th>Qubit RNA Conc. (ng/ul)</th>
                                <th>Integrity Number</th>
                                <th>Comments</th>
                            </tr>
                        </thead>
                        <tbody>
                            <tr>
                                <td>Sample ID</td>
                                <td>theraCUES Sample ID</td>
                                <td>Qubit RNA Conc. (ng/ul)</td>
                                <td>Integrity Number</td>
                                <td>Comments</td>
                            </tr>
                            <tr>
                                <td>Sample ID</td>
                                <td>theraCUES Sample ID</td>
                                <td>Qubit RNA Conc. (ng/ul)</td>
                                <td>Integrity Number</td>
                                <td>Comments</td>
                            </tr>
                            <tr>
                                <td>Sample ID</td>
                                <td>theraCUES Sample ID</td>
                                <td>Qubit RNA Conc. (ng/ul)</td>
                                <td>Integrity Number</td>
                                <td>Comments</td>
                            </tr>
                            <tr>
                                <td>Sample ID</td>
                                <td>theraCUES Sample ID</td>
                                <td>Qubit RNA Conc. (ng/ul)</td>
                                <td>Integrity Number</td>
                                <td>Comments</td>
                            </tr>
                            <tr>
                                <td>Sample ID</td>
                                <td>theraCUES Sample ID</td>
                                <td>Qubit RNA Conc. (ng/ul)</td>
                                <td>Integrity Number</td>
                                <td>Comments</td>
                            </tr>
                            <tr>
                                <td>Sample ID</td>
                                <td>theraCUES Sample ID</td>
                                <td>Qubit RNA Conc. (ng/ul)</td>
                                <td>Integrity Number</td>
                                <td>Comments</td>
                            </tr>
                            <tr>
                                <td>Sample ID</td>
                                <td>theraCUES Sample ID</td>
                                <td>Qubit RNA Conc. (ng/ul)</td>
                                <td>Integrity Number</td>
                                <td>Comments</td>
                            </tr>
                        </tbody>
                    </table>
            </div>

            <div class="general-cont">
                <div class="overview-head">
                    <div class="footer-comp"><h3>Comments</h3></div>
                    <div class="footer-comp-tab">
                        <p>All samples were quantitated by Qubit RNA HS assay and integrity check done on Agilent Bioanalyzer. Kindly review the report. </p>
                    </div>
                </div>
            </div>




            <div class="general-cont">
            
                <div class="footer-comp"><h3>For Queries</h3></div>
                <div class="footer-comp-tab-c">
                    <div>Kindly Contact:</div> 
                    <div>Project Management Team</div> 
                    <div>TheraCUES Innovations Pvt. Ltd. </div>
                    <div>Bangalore - 560 092 </div>
                    <div>Phone: +91 80 4866 1874 </div>
                    <div>Email- projectmgt@theracues.com </div>
                </div>
    
            </div>

        </div>
    </body>
</html>


"""

# %%
HTML(string=template).write_pdf("document.pdf", pdf_variant="pdf/a-3u")

# %%
from utils.dbfunc import collections_load        

collection = collections_load("tcProjects")

data = collection.find({},
                        {
                            "_id" : 0,
                            "project_status" : 1
                        })
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from utils.dbfunc import collections_load
#       3 collection = collections_load("tcProjects")
#       5 data = collection.find({},
#       6                         {
#       7                             "_id" : 0,
#       8                             "project_status" : 1
#       9                         })
#
# ModuleNotFoundError: No module named 'utils'

# %%
from pprint import pprint
from pymongo import MongoClient

CLIENT = MongoClient("mongodb://localhost:27017")

db = CLIENT.tcDB

collections = db["tcStdDeliverables"]

data = collections.find({},{
    "_id" : 0,
    "category" : 1,
    "services"
    ".service_name" : 1,
    "services.service_code" :  1
})

# %%
data

# %%
data_set = []

for doc in data:
    data_set.append(doc)

# %%
data_set
# Out:
# [{'category': 'Bulk Transcriptomics',
#   'services': [{'service_name': 'RNA-seq (Eukaryotic Poly-A | With Reference Genome)',
#     'service_code': 'BT-EPAM-MDL'},
#    {'service_name': 'RNA-seq (Eukaryotic Poly-A | Non-Model Organism - De Novo)',
#     'service_code': 'BT-EPAN-NMD'},
#    {'service_name': 'RNA-seq (Total RNA | Human / Mouse / Rat)',
#     'service_code': 'BT-TRNA-HMR'},
#    {'service_name': 'RNA-seq (Bacterial | With Reference Genome)',
#     'service_code': 'BT-BRNA-REF'},
#    {'service_name': "RNA-seq (Blood | 3' End Tagging)",
#     'service_code': 'BT-BACT-BLD'},
#    {'service_name': 'RNA-seq (FFPE | Human / Mouse / Rat | With Reference Genome)',
#     'service_code': 'BT-FFPE-HUM'},
#    {'service_name': 'FFPE Cancer Transcriptome (Discovery RNA-seq | Human)',
#     'service_code': 'BT-FFPE-DIS'},
#    {'service_name': 'RNA-seq (Plant / Microbial | Host-Pathogen Co-expression)',
#     'service_code': 'BT-HPCE-PLT'},
# ...

# %%
len(data_set)
# Out:
# 3

# %%
pprint(data_set)
# Out:
# [{'project_id': 'TCP_2627_1001',
#   'project_status': {'bioinformatics': True,
#                      'closed': True,
#                      'library': True,
#                      'method': True,
#                      'project_details': True,
#                      'project_info': True,
#                      'qc': True,
#                      'sample_submission': True,
#                      'service_info': True}},
#  {'project_id': 'TCP_2627_1002',
#   'project_status': {'bioinformatics': True,
#                      'closed': True,
#                      'library': True,
#                      'method': True,
#                      'project_details': True,
#                      'project_info': True,
#                      'qc': True,
#                      'sample_submission': True,
#                      'service_info': True}},
#  {'project_id': 'TCP_2526_1009',
#   'project_status': {'bioinformatics': True,
#                      'closed': True,
# ...

# %%
data_set[0]
# Out:
# {'project_id': 'TCP_2627_1001',
#  'project_status': {'project_info': True,
#   'service_info': True,
#   'project_details': True,
#   'sample_submission': True,
#   'method': True,
#   'qc': True,
#   'library': True,
#   'bioinformatics': True,
#   'closed': True}}

# %%
closed = 0
bioinformatics = 0
library = 0
qc = 0
accepted  = 0
initiated = 0


for ps in data_set:
    flags = ps.get("project_status")

    if flags.get("closed"):
        closed += 1
        continue

    if flags.get("bioinformatics"):
        bioinformatics += 1
        continue

    if flags.get("library"):
        library += 1
        continue

    if flags.get("qc"):
        qc += 1
        continue

    if flags.get("sample_submission"):
        accepted += 1
        continue

    if flags.get("service_info"):
        initiated += 1
        continue

# %%
bioinformatics
# Out:
# 0
